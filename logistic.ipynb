# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\utkar\1csv\1stlog.csv")
df
# Out:
#      x  y
# 0   34  0
# 1   70  1
# 2   12  0
# 3   61  1
# 4   84  1
# 5   21  0
# 6   14  0
# 7   31  0
# 8   29  0
# 9   98  1
# 10  74  1
# 11  88  1
# 12  26  0
# 13  20  1
# 14  50  0

# %%
plt.scatter(df.x,df.y,marker="*",color="red")
plt
# Out:
# <module 'matplotlib.pyplot' from 'D:\\sem4\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['x']], df['y'], test_size=0.2)

# %%
len(x_train)
# Out:
# 12

# %%
from sklearn.linear_model import LogisticRegression
model= LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[84]])
# Out:
# D:\sem4\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
