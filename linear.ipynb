# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv(r'C:\Users\utkar\1csv\1st check.csv')
df
# Out:
#    x  y
# 0  1  3
# 1  2  4
# 2  3  2
# 3  4  4
# 4  5  5

# %%
plt.xlabel ('x')
plt.ylabel ('y')
plt.scatter(df.x , df.y , color='red' , marker=('*'))

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['x']],df.y)
# Out:
# LinearRegression()

# %%
reg.predict([[3]])
# Out:
# D:\sem4\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.6])
