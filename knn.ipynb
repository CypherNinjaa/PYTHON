# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier

# %%
data = pd.DataFrame({
    "X1" : [5,3,7,4,6,8],
    "X2" : [2,6,2,3,7,1],
    "Y" : [1,0,0,1,1,0]
})
df = pd.DataFrame(data)
df
# Out:
#    X1  X2  Y
# 0   5   2  1
# 1   3   6  0
# 2   7   2  0
# 3   4   3  1
# 4   6   7  1
# 5   8   1  0

# %%
plt.xlabel('X1')
plt.ylabel('X2')
plt.scatter(df.X1, df.X2, c=df.Y)
plt.show()

# %%
model = KNeighborsClassifier(n_neighbors=2)

# %%
model.fit(df[['X1','X2']], df.Y)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
prediction = model.predict([[5,2]])
print("Predicted Label:", prediction[0])
# Out:
# Predicted Label: 1
# D:\sem4\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction = model.predict([[5000000,-200000000000000000000000]])
print("Predicted Label:", prediction[0])
# Out:
# Predicted Label: 1
# D:\sem4\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
prediction = model.predict([[6,2]])
print("Predicted Label:", prediction[0])
# Out:
# Predicted Label: 0
# D:\sem4\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
